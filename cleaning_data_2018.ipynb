# %%
# import dependencies
from pathlib import Path
import pandas as pd

# %%
# read the forbes_2022_billionaires.csv file into a dataframe
data = Path('Resources/forbes_2018_billionaires.csv')
df = pd.read_csv(data)
df.head()
# Out:
#    Rank             Name   Age              Source                 Industry  \
# 0   1.0       Jeff Bezos  54.0              Amazon               Technology
# 1   2.0       Bill Gates  62.0           Microsoft               Technology
# 2   3.0   Warren Buffett  87.0  Berkshire Hathaway  Finance and Investments
# 3   4.0  Bernard Arnault  69.0                LVMH         Fashion & Retail
# 4   5.0  Mark Zuckerberg  33.0            Facebook               Technology
#
#   Gender      Continent        Country Headquarters       State  Net Worth  \
# 0   Male  North America  United States           WA  Washington      112.0
# 1   Male  North America  United States           WA  Washington       90.0
# 2   Male  North America  United States           NE    Nebraska       84.0
# 3   Male         Europe         France          NaN         NaN       72.0
# 4   Male  North America  United States           CA  California       71.0
#
#                                                Title
# 0                        CEO and Founder, Amazon.com
# 1         Cofounder, Bill & Melinda Gates Foundation
# 2                            CEO, Berkshire Hathaway
# 3  Chairman and CEO, LVMH Moet Hennessy Louis Vui...
# 4              Cofounder, Chairman and CEO, Facebook

# %%
# print column names
df.columns
# Out:
# Index(['Rank', 'Name', 'Age', 'Source', 'Industry', 'Gender', 'Continent',
#        'Country', 'Headquarters', 'State', 'Net Worth', 'Title'],
#       dtype='object')

# %%
# drop unnecessary columns ['year', 'month', 'countryOfCitizenship', 'source', 'state', 'city', 'organization', 'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio', 'about', 'title']
cols = ['Continent', 'Source', 'State', 'Headquarters', 'Title']

df = df.drop(columns=cols)
df.head()
# Out:
#    Rank             Name   Age                 Industry Gender        Country  \
# 0   1.0       Jeff Bezos  54.0               Technology   Male  United States
# 1   2.0       Bill Gates  62.0               Technology   Male  United States
# 2   3.0   Warren Buffett  87.0  Finance and Investments   Male  United States
# 3   4.0  Bernard Arnault  69.0         Fashion & Retail   Male         France
# 4   5.0  Mark Zuckerberg  33.0               Technology   Male  United States
#
#    Net Worth
# 0      112.0
# 1       90.0
# 2       84.0
# 3       72.0
# 4       71.0

# %%
# Rename columns
df = df.rename(columns={"Rank":"rank", "Name":"personName", "Age":"age", "Industry":"category", "Gender":"gender", "Country":"country", "Net Worth":"finalWorth"})
df.head()
# Out:
#    rank       personName   age                 category gender        country  \
# 0   1.0       Jeff Bezos  54.0               Technology   Male  United States
# 1   2.0       Bill Gates  62.0               Technology   Male  United States
# 2   3.0   Warren Buffett  87.0  Finance and Investments   Male  United States
# 3   4.0  Bernard Arnault  69.0         Fashion & Retail   Male         France
# 4   5.0  Mark Zuckerberg  33.0               Technology   Male  United States
#
#    finalWorth
# 0       112.0
# 1        90.0
# 2        84.0
# 3        72.0
# 4        71.0

# %%
# Reorder columns
df = df[["rank", "personName", "age", "finalWorth", "category", "country","gender"]]
df.head()
# Out:
#    rank       personName   age  finalWorth                 category  \
# 0   1.0       Jeff Bezos  54.0       112.0               Technology
# 1   2.0       Bill Gates  62.0        90.0               Technology
# 2   3.0   Warren Buffett  87.0        84.0  Finance and Investments
# 3   4.0  Bernard Arnault  69.0        72.0         Fashion & Retail
# 4   5.0  Mark Zuckerberg  33.0        71.0               Technology
#
#          country gender
# 0  United States   Male
# 1  United States   Male
# 2  United States   Male
# 3         France   Male
# 4  United States   Male

# %%
# Replace values in the 'category' column: Change 'and' to '&'
df["category"] = [x.replace("and","&") for x in df["category"]]

df.head()
# Out:
#    rank       personName   age  finalWorth               category  \
# 0   1.0       Jeff Bezos  54.0       112.0             Technology
# 1   2.0       Bill Gates  62.0        90.0             Technology
# 2   3.0   Warren Buffett  87.0        84.0  Finance & Investments
# 3   4.0  Bernard Arnault  69.0        72.0       Fashion & Retail
# 4   5.0  Mark Zuckerberg  33.0        71.0             Technology
#
#          country gender
# 0  United States   Male
# 1  United States   Male
# 2  United States   Male
# 3         France   Male
# 4  United States   Male

# %%
# Drop NaN values
df_cleaned = df.dropna()
df_cleaned
# Out:
#         rank       personName   age  finalWorth               category  \
# 0        1.0       Jeff Bezos  54.0       112.0             Technology
# 1        2.0       Bill Gates  62.0        90.0             Technology
# 2        3.0   Warren Buffett  87.0        84.0  Finance & Investments
# 3        4.0  Bernard Arnault  69.0        72.0       Fashion & Retail
# 4        5.0  Mark Zuckerberg  33.0        71.0             Technology
# ...      ...              ...   ...         ...                    ...
# 2203  2124.0   Zhao Xiaoqiang  50.0         1.0       Fashion & Retail
# 2204  2124.0  Zhou Liangzhang  55.0         1.0          Manufacturing
# 2205  2124.0     Zhu Xingming  51.0         1.0          Manufacturing
# 2206  2124.0         Zhuo Jun  52.0         1.0          Manufacturing
# 2207  2124.0      Olgun Zorlu  54.0         1.0            Diversified
#
#             country  gender
# 0     United States    Male
# 1     United States    Male
# 2     United States    Male
# 3            France    Male
# 4     United States    Male
# ...             ...     ...
# 2203          China    Male
# 2204          China    Male
# 2205          China    Male
# 2206      Hong Kong  Female
# 2207         Turkey    Male
#
# [2135 rows x 7 columns]

# %%
# Check data types
df_cleaned.dtypes
# Out:
# rank          float64
# personName     object
# age           float64
# finalWorth    float64
# category       object
# country        object
# gender         object
# dtype: object

# %%
# Change rank and finalWorth into int64 data types
df_cleaned[["rank", "finalWorth"]] = df_cleaned[["rank", "finalWorth"]].astype('int64')
df_cleaned.head()
# Out:
# /var/folders/p2/4xqb8d592jgg64n9njlff3380000gn/T/ipykernel_17634/386205516.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned[["rank", "finalWorth"]] = df_cleaned[["rank", "finalWorth"]].astype('int64')
#    rank       personName   age  finalWorth               category  \
# 0     1       Jeff Bezos  54.0         112             Technology
# 1     2       Bill Gates  62.0          90             Technology
# 2     3   Warren Buffett  87.0          84  Finance & Investments
# 3     4  Bernard Arnault  69.0          72       Fashion & Retail
# 4     5  Mark Zuckerberg  33.0          71             Technology
#
#          country gender
# 0  United States   Male
# 1  United States   Male
# 2  United States   Male
# 3         France   Male
# 4  United States   Male

# %%
# x1000 for each value in finalWorth to standardize the values between the 2018 and 2022 data
df_cleaned["finalWorth"] = [x * 1000 for x in df_cleaned["finalWorth"]]
df_cleaned.head()
# Out:
# /var/folders/p2/4xqb8d592jgg64n9njlff3380000gn/T/ipykernel_17634/2967407993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned["finalWorth"] = [x * 1000 for x in df_cleaned["finalWorth"]]
#    rank       personName   age  finalWorth               category  \
# 0     1       Jeff Bezos  54.0      112000             Technology
# 1     2       Bill Gates  62.0       90000             Technology
# 2     3   Warren Buffett  87.0       84000  Finance & Investments
# 3     4  Bernard Arnault  69.0       72000       Fashion & Retail
# 4     5  Mark Zuckerberg  33.0       71000             Technology
#
#          country gender
# 0  United States   Male
# 1  United States   Male
# 2  United States   Male
# 3         France   Male
# 4  United States   Male

# %%
df_cleaned["gender"] = [x[0] if x == "Male" else x[0] for x in df_cleaned["gender"]]
df_cleaned.head()
# Out:
# /var/folders/p2/4xqb8d592jgg64n9njlff3380000gn/T/ipykernel_17634/2043840714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned["gender"] = [x[0] if x == "Male" else x[0] for x in df_cleaned["gender"]]
#    rank       personName   age  finalWorth               category  \
# 0     1       Jeff Bezos  54.0      112000             Technology
# 1     2       Bill Gates  62.0       90000             Technology
# 2     3   Warren Buffett  87.0       84000  Finance & Investments
# 3     4  Bernard Arnault  69.0       72000       Fashion & Retail
# 4     5  Mark Zuckerberg  33.0       71000             Technology
#
#          country gender
# 0  United States      M
# 1  United States      M
# 2  United States      M
# 3         France      M
# 4  United States      M

# %%
# check for duplicates
df_cleaned.drop_duplicates()

# Note: when comparing drop_duplicates dataframe with the above dataframe,
# there are the same number of rows - there are no duplicates in the data.
# Out:
#       rank       personName   age  finalWorth               category  \
# 0        1       Jeff Bezos  54.0      112000             Technology
# 1        2       Bill Gates  62.0       90000             Technology
# 2        3   Warren Buffett  87.0       84000  Finance & Investments
# 3        4  Bernard Arnault  69.0       72000       Fashion & Retail
# 4        5  Mark Zuckerberg  33.0       71000             Technology
# ...    ...              ...   ...         ...                    ...
# 2203  2124   Zhao Xiaoqiang  50.0        1000       Fashion & Retail
# 2204  2124  Zhou Liangzhang  55.0        1000          Manufacturing
# 2205  2124     Zhu Xingming  51.0        1000          Manufacturing
# 2206  2124         Zhuo Jun  52.0        1000          Manufacturing
# 2207  2124      Olgun Zorlu  54.0        1000            Diversified
#
#             country gender
# 0     United States      M
# 1     United States      M
# 2     United States      M
# 3            France      M
# 4     United States      M
# ...             ...    ...
# 2203          China      M
# 2204          China      M
# 2205          China      M
# 2206      Hong Kong      F
# 2207         Turkey      M
#
# [2135 rows x 7 columns]

# %%
# saving cleaned data to csv

file_path = "Resources/cleaned_2018_billionaire.csv"
df_cleaned.to_csv(file_path, index=False)
