# %%
# import dependencies
from pathlib import Path
import pandas as pd

# %%
# read the forbes_2022_billionaires.csv file into a dataframe
data = Path('Resources/forbes_2018_billionaires.csv')
df = pd.read_csv(data)
df.head()
# Out:
#    Rank             Name   Age              Source                 Industry  \
# 0   1.0       Jeff Bezos  54.0              Amazon               Technology
# 1   2.0       Bill Gates  62.0           Microsoft               Technology
# 2   3.0   Warren Buffett  87.0  Berkshire Hathaway  Finance and Investments
# 3   4.0  Bernard Arnault  69.0                LVMH         Fashion & Retail
# 4   5.0  Mark Zuckerberg  33.0            Facebook               Technology
#
#   Gender      Continent        Country Headquarters       State  Net Worth  \
# 0   Male  North America  United States           WA  Washington      112.0
# 1   Male  North America  United States           WA  Washington       90.0
# 2   Male  North America  United States           NE    Nebraska       84.0
# 3   Male         Europe         France          NaN         NaN       72.0
# 4   Male  North America  United States           CA  California       71.0
#
#                                                Title
# 0                        CEO and Founder, Amazon.com
# 1         Cofounder, Bill & Melinda Gates Foundation
# 2                            CEO, Berkshire Hathaway
# 3  Chairman and CEO, LVMH Moet Hennessy Louis Vui...
# 4              Cofounder, Chairman and CEO, Facebook

# %%
# print column names
df.columns
# Out:
# Index(['Rank', 'Name', 'Age', 'Source', 'Industry', 'Gender', 'Continent',
#        'Country', 'Headquarters', 'State', 'Net Worth', 'Title'],
#       dtype='object')

# %%
# drop unnecessary columns ['year', 'month', 'countryOfCitizenship', 'source', 'state', 'city', 'organization', 'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio', 'about', 'title']
cols = ['Continent', 'Source', 'State', 'Headquarters', 'Title']

df = df.drop(columns=cols)
df.head()
# Out:
#    Rank             Name   Age                 Industry Gender        Country  \
# 0   1.0       Jeff Bezos  54.0               Technology   Male  United States
# 1   2.0       Bill Gates  62.0               Technology   Male  United States
# 2   3.0   Warren Buffett  87.0  Finance and Investments   Male  United States
# 3   4.0  Bernard Arnault  69.0         Fashion & Retail   Male         France
# 4   5.0  Mark Zuckerberg  33.0               Technology   Male  United States
#
#    Net Worth
# 0      112.0
# 1       90.0
# 2       84.0
# 3       72.0
# 4       71.0

# %%
# Rename columns
df = df.rename(columns={"Rank":"rank", "Name":"personName", "Age":"age", "Industry":"category", "Gender":"gender", "Country":"country", "Net Worth":"finalWorth"})
df.head()
# Out:
#    rank       personName   age                 category gender        country  \
# 0   1.0       Jeff Bezos  54.0               Technology   Male  United States
# 1   2.0       Bill Gates  62.0               Technology   Male  United States
# 2   3.0   Warren Buffett  87.0  Finance and Investments   Male  United States
# 3   4.0  Bernard Arnault  69.0         Fashion & Retail   Male         France
# 4   5.0  Mark Zuckerberg  33.0               Technology   Male  United States
#
#    finalWorth
# 0       112.0
# 1        90.0
# 2        84.0
# 3        72.0
# 4        71.0

# %%
# Reorder columns
df = df[["rank", "personName", "age", "finalWorth", "category", "country","gender"]]
df.head()
# Out:
#    rank       personName   age  finalWorth                 category  \
# 0   1.0       Jeff Bezos  54.0       112.0               Technology
# 1   2.0       Bill Gates  62.0        90.0               Technology
# 2   3.0   Warren Buffett  87.0        84.0  Finance and Investments
# 3   4.0  Bernard Arnault  69.0        72.0         Fashion & Retail
# 4   5.0  Mark Zuckerberg  33.0        71.0               Technology
#
#          country gender
# 0  United States   Male
# 1  United States   Male
# 2  United States   Male
# 3         France   Male
# 4  United States   Male

# %%
# Replace values in the 'category' column: Change 'and' to '&'
df["category"] = [x.replace("and","&") for x in df["category"]]

df.head()
# Out:
#    rank       personName   age  finalWorth               category  \
# 0   1.0       Jeff Bezos  54.0       112.0             Technology
# 1   2.0       Bill Gates  62.0        90.0             Technology
# 2   3.0   Warren Buffett  87.0        84.0  Finance & Investments
# 3   4.0  Bernard Arnault  69.0        72.0       Fashion & Retail
# 4   5.0  Mark Zuckerberg  33.0        71.0             Technology
#
#          country gender
# 0  United States   Male
# 1  United States   Male
# 2  United States   Male
# 3         France   Male
# 4  United States   Male

# %%
# Drop NaN values
df_cleaned = df.dropna()
df_cleaned
# Out:
#         rank       personName   age  finalWorth               category  \
# 0        1.0       Jeff Bezos  54.0       112.0             Technology
# 1        2.0       Bill Gates  62.0        90.0             Technology
# 2        3.0   Warren Buffett  87.0        84.0  Finance & Investments
# 3        4.0  Bernard Arnault  69.0        72.0       Fashion & Retail
# 4        5.0  Mark Zuckerberg  33.0        71.0             Technology
# ...      ...              ...   ...         ...                    ...
# 2203  2124.0   Zhao Xiaoqiang  50.0         1.0       Fashion & Retail
# 2204  2124.0  Zhou Liangzhang  55.0         1.0          Manufacturing
# 2205  2124.0     Zhu Xingming  51.0         1.0          Manufacturing
# 2206  2124.0         Zhuo Jun  52.0         1.0          Manufacturing
# 2207  2124.0      Olgun Zorlu  54.0         1.0            Diversified
#
#             country  gender
# 0     United States    Male
# 1     United States    Male
# 2     United States    Male
# 3            France    Male
# 4     United States    Male
# ...             ...     ...
# 2203          China    Male
# 2204          China    Male
# 2205          China    Male
# 2206      Hong Kong  Female
# 2207         Turkey    Male
#
# [2135 rows x 7 columns]

# %%
# Check data types
df_cleaned.dtypes
# Out:
# rank          float64
# personName     object
# age           float64
# finalWorth    float64
# category       object
# country        object
# gender         object
# dtype: object

# %%
# Change rank and finalWorth into int64 data types
df_cleaned[["rank", "finalWorth"]] = df_cleaned[["rank", "finalWorth"]].astype('int64')
df_cleaned.head()
# Out:
# /var/folders/p2/4xqb8d592jgg64n9njlff3380000gn/T/ipykernel_82589/386205516.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned[["rank", "finalWorth"]] = df_cleaned[["rank", "finalWorth"]].astype('int64')
#    rank       personName   age  finalWorth               category  \
# 0     1       Jeff Bezos  54.0         112             Technology
# 1     2       Bill Gates  62.0          90             Technology
# 2     3   Warren Buffett  87.0          84  Finance & Investments
# 3     4  Bernard Arnault  69.0          72       Fashion & Retail
# 4     5  Mark Zuckerberg  33.0          71             Technology
#
#          country gender
# 0  United States   Male
# 1  United States   Male
# 2  United States   Male
# 3         France   Male
# 4  United States   Male

# %%
# x1000 for each value in finalWorth to standardize the values between the 2018 and 2022 data
df_cleaned["finalWorth"] = [x * 1000 for x in df_cleaned["finalWorth"]]
df_cleaned.head()
# Out:
# /var/folders/p2/4xqb8d592jgg64n9njlff3380000gn/T/ipykernel_82589/2967407993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned["finalWorth"] = [x * 1000 for x in df_cleaned["finalWorth"]]
#    rank       personName   age  finalWorth               category  \
# 0     1       Jeff Bezos  54.0      112000             Technology
# 1     2       Bill Gates  62.0       90000             Technology
# 2     3   Warren Buffett  87.0       84000  Finance & Investments
# 3     4  Bernard Arnault  69.0       72000       Fashion & Retail
# 4     5  Mark Zuckerberg  33.0       71000             Technology
#
#          country gender
# 0  United States   Male
# 1  United States   Male
# 2  United States   Male
# 3         France   Male
# 4  United States   Male

# %%
df_cleaned["gender"] = [x[0] if x == "Male" else x[0] for x in df_cleaned["gender"]]
df_cleaned.head()
# Out:
# /var/folders/p2/4xqb8d592jgg64n9njlff3380000gn/T/ipykernel_82589/2043840714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned["gender"] = [x[0] if x == "Male" else x[0] for x in df_cleaned["gender"]]
#    rank       personName   age  finalWorth               category  \
# 0     1       Jeff Bezos  54.0      112000             Technology
# 1     2       Bill Gates  62.0       90000             Technology
# 2     3   Warren Buffett  87.0       84000  Finance & Investments
# 3     4  Bernard Arnault  69.0       72000       Fashion & Retail
# 4     5  Mark Zuckerberg  33.0       71000             Technology
#
#          country gender
# 0  United States      M
# 1  United States      M
# 2  United States      M
# 3         France      M
# 4  United States      M

# %%
# check for duplicates
df_cleaned.drop_duplicates()

# Note: when comparing drop_duplicates dataframe with the above dataframe,
# there are the same number of rows - there are no duplicates in the data.
# Out:
#       rank       personName   age  finalWorth               category  \
# 0        1       Jeff Bezos  54.0      112000             Technology
# 1        2       Bill Gates  62.0       90000             Technology
# 2        3   Warren Buffett  87.0       84000  Finance & Investments
# 3        4  Bernard Arnault  69.0       72000       Fashion & Retail
# 4        5  Mark Zuckerberg  33.0       71000             Technology
# ...    ...              ...   ...         ...                    ...
# 2203  2124   Zhao Xiaoqiang  50.0        1000       Fashion & Retail
# 2204  2124  Zhou Liangzhang  55.0        1000          Manufacturing
# 2205  2124     Zhu Xingming  51.0        1000          Manufacturing
# 2206  2124         Zhuo Jun  52.0        1000          Manufacturing
# 2207  2124      Olgun Zorlu  54.0        1000            Diversified
#
#             country gender
# 0     United States      M
# 1     United States      M
# 2     United States      M
# 3            France      M
# 4     United States      M
# ...             ...    ...
# 2203          China      M
# 2204          China      M
# 2205          China      M
# 2206      Hong Kong      F
# 2207         Turkey      M
#
# [2135 rows x 7 columns]

# %%
copy_df_cleaned = df_cleaned.copy()
copy_df_cleaned
# Out:
#       rank       personName   age  finalWorth               category  \
# 0        1       Jeff Bezos  54.0      112000             Technology
# 1        2       Bill Gates  62.0       90000             Technology
# 2        3   Warren Buffett  87.0       84000  Finance & Investments
# 3        4  Bernard Arnault  69.0       72000       Fashion & Retail
# 4        5  Mark Zuckerberg  33.0       71000             Technology
# ...    ...              ...   ...         ...                    ...
# 2203  2124   Zhao Xiaoqiang  50.0        1000       Fashion & Retail
# 2204  2124  Zhou Liangzhang  55.0        1000          Manufacturing
# 2205  2124     Zhu Xingming  51.0        1000          Manufacturing
# 2206  2124         Zhuo Jun  52.0        1000          Manufacturing
# 2207  2124      Olgun Zorlu  54.0        1000            Diversified
#
#             country gender
# 0     United States      M
# 1     United States      M
# 2     United States      M
# 3            France      M
# 4     United States      M
# ...             ...    ...
# 2203          China      M
# 2204          China      M
# 2205          China      M
# 2206      Hong Kong      F
# 2207         Turkey      M
#
# [2135 rows x 7 columns]

# %%
copy_df_cleaned["finalWorth>4799"] = ["1" if value > 4799 else "0" for value in df_cleaned["finalWorth"]]
copy_df_cleaned
# Out:
#       rank       personName   age  finalWorth               category  \
# 0        1       Jeff Bezos  54.0      112000             Technology
# 1        2       Bill Gates  62.0       90000             Technology
# 2        3   Warren Buffett  87.0       84000  Finance & Investments
# 3        4  Bernard Arnault  69.0       72000       Fashion & Retail
# 4        5  Mark Zuckerberg  33.0       71000             Technology
# ...    ...              ...   ...         ...                    ...
# 2203  2124   Zhao Xiaoqiang  50.0        1000       Fashion & Retail
# 2204  2124  Zhou Liangzhang  55.0        1000          Manufacturing
# 2205  2124     Zhu Xingming  51.0        1000          Manufacturing
# 2206  2124         Zhuo Jun  52.0        1000          Manufacturing
# 2207  2124      Olgun Zorlu  54.0        1000            Diversified
#
#             country gender finalWorth>4799
# 0     United States      M               1
# 1     United States      M               1
# 2     United States      M               1
# 3            France      M               1
# 4     United States      M               1
# ...             ...    ...             ...
# 2203          China      M               0
# 2204          China      M               0
# 2205          China      M               0
# 2206      Hong Kong      F               0
# 2207         Turkey      M               0
#
# [2135 rows x 8 columns]

# %%
# save this version of the data for the Tableau visualizations
copy_df_cleaned.to_csv('Resources/finalWorth_labeled_cleaned_2018_billionaire.csv', index=False)

# %%
# Encoding gender to numerical binary values in cleaned dataframe. This will split the gender column into seperate columns on for female and one for male
# 0=false and 1=true 
df_cleaned = pd.get_dummies(df_cleaned, columns=["gender"])
df_cleaned
# Out:
#       rank       personName   age  finalWorth               category  \
# 0        1       Jeff Bezos  54.0      112000             Technology
# 1        2       Bill Gates  62.0       90000             Technology
# 2        3   Warren Buffett  87.0       84000  Finance & Investments
# 3        4  Bernard Arnault  69.0       72000       Fashion & Retail
# 4        5  Mark Zuckerberg  33.0       71000             Technology
# ...    ...              ...   ...         ...                    ...
# 2203  2124   Zhao Xiaoqiang  50.0        1000       Fashion & Retail
# 2204  2124  Zhou Liangzhang  55.0        1000          Manufacturing
# 2205  2124     Zhu Xingming  51.0        1000          Manufacturing
# 2206  2124         Zhuo Jun  52.0        1000          Manufacturing
# 2207  2124      Olgun Zorlu  54.0        1000            Diversified
#
#             country  gender_F  gender_M
# 0     United States         0         1
# 1     United States         0         1
# 2     United States         0         1
# 3            France         0         1
# 4     United States         0         1
# ...             ...       ...       ...
# 2203          China         0         1
# 2204          China         0         1
# 2205          China         0         1
# 2206      Hong Kong         1         0
# 2207         Turkey         0         1
#
# [2135 rows x 8 columns]

# %%
# Convert country column into numerical values
# Since there are more than two countries we can't use a numerical binary value to encode the country column
# Instead we have to create a custom country dictionary, and assign a specific numerical value for each unique country
# Process below is turning the country column into a list, remove duplicates, assign numerical values, and then encode the country column in the cleaned_df

# Convert Country Column to list 
country_list = df_cleaned["country"].values.tolist()

# Remove duplicate values from country list
country_list = list(set(country_list))
country_list
# Out:
# ['Cyprus',
#  'United Arab Emirates',
#  'Netherlands',
#  'India',
#  'France',
#  'Ukraine',
#  'Kuwait',
#  'Hungary',
#  'Morocco',
#  'Nepal',
#  'Zimbabwe',
#  'Singapore',
#  'Germany',
#  'New Zealand',
#  'Switzerland',
#  'Portugal',
#  'St. Kitts and Nevis',
#  'China',
#  'Hong Kong',
#  'Argentina',
#  'Russia',
#  'South Korea',
#  'Japan',
#  'Chile',
#  'Venezuela',
#  'Guernsey',
#  'Monaco',
#  'Colombia',
#  'Georgia',
#  'Nigeria',
#  'Peru',
#  'Oman',
#  'Canada',
#  'Angola',
#  'Czech Republic',
#  'Mexico',
#  'Taiwan',
#  'Australia',
#  'Qatar',
#  'Romania',
#  'Swaziland',
#  'Indonesia',
#  'Slovakia',
#  'Algeria',
#  'Greece',
#  'Brazil',
#  'Sweden',
#  'Belgium',
#  'Turkey',
#  'Philippines',
#  'Finland',
#  'Denmark',
#  'Iceland',
#  'Thailand',
#  'Austria',
#  'Norway',
#  'Poland',
#  'Ireland',
#  'Lebanon',
#  'United Kingdom',
#  'Tanzania',
#  'Macau',
#  'Kazakhstan',
#  'Spain',
#  'Israel',
#  'South Africa',
#  'Vietnam',
#  'Liechtenstein',
#  'Italy',
#  'Malaysia',
#  'Egypt',
#  'United States']

# %%
# Enumerate list and convert to dictionary
country_dict = {key: i for i, key in enumerate(country_list)}
country_dict
# Out:
# {'Cyprus': 0,
#  'United Arab Emirates': 1,
#  'Netherlands': 2,
#  'India': 3,
#  'France': 4,
#  'Ukraine': 5,
#  'Kuwait': 6,
#  'Hungary': 7,
#  'Morocco': 8,
#  'Nepal': 9,
#  'Zimbabwe': 10,
#  'Singapore': 11,
#  'Germany': 12,
#  'New Zealand': 13,
#  'Switzerland': 14,
#  'Portugal': 15,
#  'St. Kitts and Nevis': 16,
#  'China': 17,
#  'Hong Kong': 18,
#  'Argentina': 19,
#  'Russia': 20,
#  'South Korea': 21,
#  'Japan': 22,
#  'Chile': 23,
#  'Venezuela': 24,
#  'Guernsey': 25,
#  'Monaco': 26,
#  'Colombia': 27,
#  'Georgia': 28,
#  'Nigeria': 29,
#  'Peru': 30,
#  'Oman': 31,
#  'Canada': 32,
#  'Angola': 33,
#  'Czech Republic': 34,
#  'Mexico': 35,
#  'Taiwan': 36,
#  'Australia': 37,
#  'Qatar': 38,
#  'Romania': 39,
#  'Swaziland': 40,
#  'Indonesia': 41,
#  'Slovakia': 42,
#  'Algeria': 43,
#  'Greece': 44,
#  'Brazil': 45,
#  'Sweden': 46,
#  'Belgium': 47,
#  'Turkey': 48,
#  'Philippines': 49,
#  'Finland': 50,
#  'Denmark': 51,
#  'Iceland': 52,
#  'Thailand': 53,
#  'Austria': 54,
#  'Norway': 55,
#  'Poland': 56,
#  'Ireland': 57,
#  'Lebanon': 58,
#  'United Kingdom': 59,
#  'Tanzania': 60,
#  'Macau': 61,
#  'Kazakhstan': 62,
#  'Spain': 63,
#  'Israel': 64,
#  'South Africa': 65,
#  'Vietnam': 66,
#  'Liechtenstein': 67,
#  'Italy': 68,
#  'Malaysia': 69,
#  'Egypt': 70,
#  'United States': 71}

# %%
# Custom numerical coding for country 
df_cleaned["country"] = df_cleaned["country"].apply(lambda x: country_dict[x])
df_cleaned
# Out:
#       rank       personName   age  finalWorth               category  country  \
# 0        1       Jeff Bezos  54.0      112000             Technology       71
# 1        2       Bill Gates  62.0       90000             Technology       71
# 2        3   Warren Buffett  87.0       84000  Finance & Investments       71
# 3        4  Bernard Arnault  69.0       72000       Fashion & Retail        4
# 4        5  Mark Zuckerberg  33.0       71000             Technology       71
# ...    ...              ...   ...         ...                    ...      ...
# 2203  2124   Zhao Xiaoqiang  50.0        1000       Fashion & Retail       17
# 2204  2124  Zhou Liangzhang  55.0        1000          Manufacturing       17
# 2205  2124     Zhu Xingming  51.0        1000          Manufacturing       17
# 2206  2124         Zhuo Jun  52.0        1000          Manufacturing       18
# 2207  2124      Olgun Zorlu  54.0        1000            Diversified       48
#
#       gender_F  gender_M
# 0            0         1
# 1            0         1
# 2            0         1
# 3            0         1
# 4            0         1
# ...        ...       ...
# 2203         0         1
# 2204         0         1
# 2205         0         1
# 2206         1         0
# 2207         0         1
#
# [2135 rows x 8 columns]

# %%
# Convert category column to list 
category_list = df_cleaned["category"].values.tolist()

# Remove duplicate values from category list
category_list = list(set(category_list))

# Enumerate list and convert to dictionary
category_dict = {key: i for i, key in enumerate(category_list)}
category_dict
# Out:
# {'Manufacturing': 0,
#  'Philanthropy/NGO': 1,
#  'Service': 2,
#  'Energy': 3,
#  'Food & Beverage': 4,
#  'Diversified': 5,
#  'Automotive': 6,
#  'Real Estate': 7,
#  'Construction & Engineering': 8,
#  'Technology': 9,
#  'Media & Entertainment': 10,
#  'Healthcare': 11,
#  'Logistics': 12,
#  'Telecom': 13,
#  'Sports': 14,
#  'Finance & Investments': 15,
#  'Gambling & Casinos': 16,
#  'Fashion & Retail': 17,
#  'Metals & Mining': 18}

# %%
# Custom numerical coding for country 
df_cleaned["category"] = df_cleaned["category"].apply(lambda x: category_dict[x])
df_cleaned
# Out:
#       rank       personName   age  finalWorth  category  country  gender_F  \
# 0        1       Jeff Bezos  54.0      112000         9       71         0
# 1        2       Bill Gates  62.0       90000         9       71         0
# 2        3   Warren Buffett  87.0       84000        15       71         0
# 3        4  Bernard Arnault  69.0       72000        17        4         0
# 4        5  Mark Zuckerberg  33.0       71000         9       71         0
# ...    ...              ...   ...         ...       ...      ...       ...
# 2203  2124   Zhao Xiaoqiang  50.0        1000        17       17         0
# 2204  2124  Zhou Liangzhang  55.0        1000         0       17         0
# 2205  2124     Zhu Xingming  51.0        1000         0       17         0
# 2206  2124         Zhuo Jun  52.0        1000         0       18         1
# 2207  2124      Olgun Zorlu  54.0        1000         5       48         0
#
#       gender_M
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 2203         1
# 2204         1
# 2205         1
# 2206         0
# 2207         1
#
# [2135 rows x 8 columns]

# %%
# Convert age from float dtype to int
df_cleaned['age'] = df_cleaned['age'].astype(int)
df_cleaned
# Out:
#       rank       personName  age  finalWorth  category  country  gender_F  \
# 0        1       Jeff Bezos   54      112000         9       71         0
# 1        2       Bill Gates   62       90000         9       71         0
# 2        3   Warren Buffett   87       84000        15       71         0
# 3        4  Bernard Arnault   69       72000        17        4         0
# 4        5  Mark Zuckerberg   33       71000         9       71         0
# ...    ...              ...  ...         ...       ...      ...       ...
# 2203  2124   Zhao Xiaoqiang   50        1000        17       17         0
# 2204  2124  Zhou Liangzhang   55        1000         0       17         0
# 2205  2124     Zhu Xingming   51        1000         0       17         0
# 2206  2124         Zhuo Jun   52        1000         0       18         1
# 2207  2124      Olgun Zorlu   54        1000         5       48         0
#
#       gender_M
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 2203         1
# 2204         1
# 2205         1
# 2206         0
# 2207         1
#
# [2135 rows x 8 columns]

# %%
df_cleaned.dtypes
# Out:
# rank           int64
# personName    object
# age            int64
# finalWorth     int64
# category       int64
# country        int64
# gender_F       uint8
# gender_M       uint8
# dtype: object

# %%
# saving cleaned data to csv
file_path = "Resources/cleaned_2018_billionaire.csv"
df_cleaned.to_csv(file_path, index=False)
