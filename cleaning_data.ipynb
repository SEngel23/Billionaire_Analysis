# %%
# import dependencies
from pathlib import Path
import pandas as pd

# %%
# read the forbes_2022_billionaires.csv file into a dataframe
data = Path('Resources/forbes_2022_billionaires.csv')
df = pd.read_csv(data)
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0      219000  2022      4
# 1     2                Jeff Bezos  58.0      171000  2022      4
# 2     3  Bernard Arnault & family  73.0      158000  2022      4
# 3     4                Bill Gates  66.0      129000  2022      4
# 4     5            Warren Buffett  91.0      118000  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# 0                             Tesla     True      M   6/28/1971
# 1                            Amazon     True      M   1/12/1964
# 2  LVMH Moët Hennessy Louis Vuitton    False      M    3/5/1949
# 3   Bill & Melinda Gates Foundation     True      M  10/28/1955
# 4                Berkshire Hathaway     True      M   8/30/1930
#
#               title philanthropyScore                 residenceMsa  \
# 0               CEO               1.0                          NaN
# 1      Entrepreneur               1.0  Seattle-Tacoma-Bellevue, WA
# 2  Chairman and CEO               NaN                          NaN
# 3         Cofounder               4.0  Seattle-Tacoma-Bellevue, WA
# 4               CEO               5.0                    Omaha, NE
#
#    numberOfSiblings                                                bio  \
# 0               NaN  Elon Musk is working to revolutionize transpor...
# 1               NaN  Jeff Bezos founded e-commerce giant Amazon in ...
# 2               NaN  Bernard Arnault oversees the LVMH empire of so...
# 3               NaN  Bill Gates turned his fortune from software fi...
# 4               NaN  Known as the "Oracle of Omaha," Warren Buffett...
#
#                                                about
# 0  Musk was accepted to a graduate program at Sta...
# 1  Growing up, Jeff Bezos worked summers on his g...
# 2  Arnault apparently wooed his wife, Helene Merc...
# 3  When Gates was a kid, he spent so much time re...
# 4  Buffett still lives in the same Omaha, Nebrask...
#
# [5 rows x 22 columns]

# %%
# print column names
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')

# %%
# drop unnecessary columns ['year', 'month', 'countryOfCitizenship', 'source', 'state', 'city', 'organization', 'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio', 'about', 'title']
cols = ['year', 'month', 'countryOfCitizenship', 'source', 'state', 'city', 'organization', 'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
       'about', 'title', 'birthDate']

df = df.drop(columns=cols)
df.head()
# Out:
#    rank                personName   age  finalWorth               category  \
# 0     1                 Elon Musk  50.0      219000             Automotive
# 1     2                Jeff Bezos  58.0      171000             Technology
# 2     3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3     4                Bill Gates  66.0      129000             Technology
# 4     5            Warren Buffett  91.0      118000  Finance & Investments
#
#          country  selfMade gender
# 0  United States      True      M
# 1  United States      True      M
# 2         France     False      M
# 3  United States      True      M
# 4  United States      True      M

# %%
# Check data types
df.dtypes
# Out:
# rank            int64
# personName     object
# age           float64
# finalWorth      int64
# category       object
# country        object
# selfMade         bool
# gender         object
# dtype: object

# %%
# count columns
df.count()
# Out:
# rank          2668
# personName    2668
# age           2582
# finalWorth    2668
# category      2668
# country       2668
# selfMade      2668
# gender        2652
# dtype: int64

# %%
# check for null values
for column in df.columns:
    print(f"Column {column} has {df[column].isnull().sum()} null values")
# Out:
# Column rank has 0 null values
# Column personName has 0 null values
# Column age has 86 null values
# Column finalWorth has 0 null values
# Column category has 0 null values
# Column country has 0 null values
# Column selfMade has 0 null values
# Column gender has 16 null values

# %%
# drop NaN values
df_cleaned = df.dropna()
df_cleaned
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0      219000             Automotive
# 1        2                Jeff Bezos  58.0      171000             Technology
# 2        3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3        4                Bill Gates  66.0      129000             Technology
# 4        5            Warren Buffett  91.0      118000  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0        1000          Manufacturing
# 2664  2578                Zhou Ruxin  59.0        1000             Technology
# 2665  2578         Wen Zhou & family  57.0        1000          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0        1000                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0        1000          Manufacturing
#
#             country  selfMade gender
# 0     United States      True      M
# 1     United States      True      M
# 2            France     False      M
# 3     United States      True      M
# 4     United States      True      M
# ...             ...       ...    ...
# 2663          China      True      M
# 2664          China      True      M
# 2665          China      True      M
# 2666          China      True      F
# 2667          China      True      M
#
# [2576 rows x 8 columns]

# %%
# check for duplicates
df_cleaned.drop_duplicates()

# Note: when comparing drop_duplicates dataframe with the above dataframe,
# there are the same number of rows - there are no duplicates in the data.
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0      219000             Automotive
# 1        2                Jeff Bezos  58.0      171000             Technology
# 2        3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3        4                Bill Gates  66.0      129000             Technology
# 4        5            Warren Buffett  91.0      118000  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0        1000          Manufacturing
# 2664  2578                Zhou Ruxin  59.0        1000             Technology
# 2665  2578         Wen Zhou & family  57.0        1000          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0        1000                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0        1000          Manufacturing
#
#             country  selfMade gender
# 0     United States      True      M
# 1     United States      True      M
# 2            France     False      M
# 3     United States      True      M
# 4     United States      True      M
# ...             ...       ...    ...
# 2663          China      True      M
# 2664          China      True      M
# 2665          China      True      M
# 2666          China      True      F
# 2667          China      True      M
#
# [2576 rows x 8 columns]

# %%
# Encoding gender to numerical binary values in cleaned dataframe. This will split the gender column into seperate columns on for female and one for male
# 0=false and 1=true 
df_cleaned = pd.get_dummies(df_cleaned, columns=["gender"])
df_cleaned
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0      219000             Automotive
# 1        2                Jeff Bezos  58.0      171000             Technology
# 2        3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3        4                Bill Gates  66.0      129000             Technology
# 4        5            Warren Buffett  91.0      118000  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0        1000          Manufacturing
# 2664  2578                Zhou Ruxin  59.0        1000             Technology
# 2665  2578         Wen Zhou & family  57.0        1000          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0        1000                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0        1000          Manufacturing
#
#             country  selfMade  gender_F  gender_M
# 0     United States      True         0         1
# 1     United States      True         0         1
# 2            France     False         0         1
# 3     United States      True         0         1
# 4     United States      True         0         1
# ...             ...       ...       ...       ...
# 2663          China      True         0         1
# 2664          China      True         0         1
# 2665          China      True         0         1
# 2666          China      True         1         0
# 2667          China      True         0         1
#
# [2576 rows x 9 columns]

# %%
# Convert country column into numerical values
# Since there are more than two countries we can't use a numerical binary value to encode the country column
# Instead we have to create a custom country dictionary, and assign a specific numerical value for each unique country
# Process below is turning the country column into a list, remove duplicates, assign numerical values, and then encode the country column in the cleaned_df

# Convert Country Column to list 
country_list = df_cleaned["country"].values.tolist()

# Remove duplicate values from country list
country_list = list(set(country_list))
country_list
# Out:
# ['United States',
#  'Netherlands',
#  'Belgium',
#  'Nepal',
#  'Qatar',
#  'United Kingdom',
#  'Thailand',
#  'Kazakhstan',
#  'Nigeria',
#  'Uruguay',
#  'Turks and Caicos Islands',
#  'Egypt',
#  'Greece',
#  'Hungary',
#  'Finland',
#  'Philippines',
#  'Poland',
#  'France',
#  'Guernsey',
#  'India',
#  'Tanzania',
#  'Chile',
#  'Eswatini (Swaziland)',
#  'Georgia',
#  'Monaco',
#  'Russia',
#  'Taiwan',
#  'Lebanon',
#  'Colombia',
#  'Austria',
#  'Liechtenstein',
#  'Portugal',
#  'Vietnam',
#  'Bermuda',
#  'Spain',
#  'Norway',
#  'Malaysia',
#  'United Arab Emirates',
#  'British Virgin Islands',
#  'South Korea',
#  'Cambodia',
#  'Germany',
#  'Sweden',
#  'Bahrain',
#  'Indonesia',
#  'Switzerland',
#  'Australia',
#  'Ukraine',
#  'Andorra',
#  'Oman',
#  'Bahamas',
#  'Mexico',
#  'Italy',
#  'Brazil',
#  'Israel',
#  'Morocco',
#  'Slovakia',
#  'Peru',
#  'New Zealand',
#  'Denmark',
#  'South Africa',
#  'Japan',
#  'Algeria',
#  'Singapore',
#  'Argentina',
#  'Czechia',
#  'Cayman Islands',
#  'Turkey',
#  'Romania',
#  'China',
#  'Hong Kong',
#  'Canada',
#  'Ireland']

# %%
# Enumerate list and convert to dictionary
country_dict = {key: i for i, key in enumerate(country_list)}
country_dict
# Out:
# {'United States': 0,
#  'Netherlands': 1,
#  'Belgium': 2,
#  'Nepal': 3,
#  'Qatar': 4,
#  'United Kingdom': 5,
#  'Thailand': 6,
#  'Kazakhstan': 7,
#  'Nigeria': 8,
#  'Uruguay': 9,
#  'Turks and Caicos Islands': 10,
#  'Egypt': 11,
#  'Greece': 12,
#  'Hungary': 13,
#  'Finland': 14,
#  'Philippines': 15,
#  'Poland': 16,
#  'France': 17,
#  'Guernsey': 18,
#  'India': 19,
#  'Tanzania': 20,
#  'Chile': 21,
#  'Eswatini (Swaziland)': 22,
#  'Georgia': 23,
#  'Monaco': 24,
#  'Russia': 25,
#  'Taiwan': 26,
#  'Lebanon': 27,
#  'Colombia': 28,
#  'Austria': 29,
#  'Liechtenstein': 30,
#  'Portugal': 31,
#  'Vietnam': 32,
#  'Bermuda': 33,
#  'Spain': 34,
#  'Norway': 35,
#  'Malaysia': 36,
#  'United Arab Emirates': 37,
#  'British Virgin Islands': 38,
#  'South Korea': 39,
#  'Cambodia': 40,
#  'Germany': 41,
#  'Sweden': 42,
#  'Bahrain': 43,
#  'Indonesia': 44,
#  'Switzerland': 45,
#  'Australia': 46,
#  'Ukraine': 47,
#  'Andorra': 48,
#  'Oman': 49,
#  'Bahamas': 50,
#  'Mexico': 51,
#  'Italy': 52,
#  'Brazil': 53,
#  'Israel': 54,
#  'Morocco': 55,
#  'Slovakia': 56,
#  'Peru': 57,
#  'New Zealand': 58,
#  'Denmark': 59,
#  'South Africa': 60,
#  'Japan': 61,
#  'Algeria': 62,
#  'Singapore': 63,
#  'Argentina': 64,
#  'Czechia': 65,
#  'Cayman Islands': 66,
#  'Turkey': 67,
#  'Romania': 68,
#  'China': 69,
#  'Hong Kong': 70,
#  'Canada': 71,
#  'Ireland': 72}

# %%
# Custom numerical coding for country 
df_cleaned["country"] = df_cleaned["country"].apply(lambda x: country_dict[x])
df_cleaned
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0      219000             Automotive
# 1        2                Jeff Bezos  58.0      171000             Technology
# 2        3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3        4                Bill Gates  66.0      129000             Technology
# 4        5            Warren Buffett  91.0      118000  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0        1000          Manufacturing
# 2664  2578                Zhou Ruxin  59.0        1000             Technology
# 2665  2578         Wen Zhou & family  57.0        1000          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0        1000                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0        1000          Manufacturing
#
#       country  selfMade  gender_F  gender_M
# 0           0      True         0         1
# 1           0      True         0         1
# 2          17     False         0         1
# 3           0      True         0         1
# 4           0      True         0         1
# ...       ...       ...       ...       ...
# 2663       69      True         0         1
# 2664       69      True         0         1
# 2665       69      True         0         1
# 2666       69      True         1         0
# 2667       69      True         0         1
#
# [2576 rows x 9 columns]

# %%
# Convert category column to list 
category_list = df_cleaned["category"].values.tolist()

# Remove duplicate values from category list
category_list = list(set(category_list))

# Enumerate list and convert to dictionary
category_dict = {key: i for i, key in enumerate(category_list)}
category_dict
# Out:
# {'Technology': 0,
#  'Construction & Engineering': 1,
#  'Healthcare': 2,
#  'Food & Beverage': 3,
#  'Service': 4,
#  'Real Estate': 5,
#  'Gambling & Casinos': 6,
#  'Finance & Investments': 7,
#  'Automotive': 8,
#  'Logistics': 9,
#  'Manufacturing': 10,
#  'Fashion & Retail': 11,
#  'Telecom': 12,
#  'Energy': 13,
#  'Media & Entertainment': 14,
#  'Sports': 15,
#  'Metals & Mining': 16,
#  'Diversified': 17}

# %%
# Custom numerical coding for country 
df_cleaned["category"] = df_cleaned["category"].apply(lambda x: category_dict[x])
df_cleaned
# Out:
#       rank                personName   age  finalWorth  category  country  \
# 0        1                 Elon Musk  50.0      219000         8        0
# 1        2                Jeff Bezos  58.0      171000         0        0
# 2        3  Bernard Arnault & family  73.0      158000        11       17
# 3        4                Bill Gates  66.0      129000         0        0
# 4        5            Warren Buffett  91.0      118000         7        0
# ...    ...                       ...   ...         ...       ...      ...
# 2663  2578             Zhang Yuqiang  66.0        1000        10       69
# 2664  2578                Zhou Ruxin  59.0        1000         0       69
# 2665  2578         Wen Zhou & family  57.0        1000        10       69
# 2666  2578      Zhou Yifeng & family  43.0        1000        13       69
# 2667  2578   Zhuang Kuilong & family  59.0        1000        10       69
#
#       selfMade  gender_F  gender_M
# 0         True         0         1
# 1         True         0         1
# 2        False         0         1
# 3         True         0         1
# 4         True         0         1
# ...        ...       ...       ...
# 2663      True         0         1
# 2664      True         0         1
# 2665      True         0         1
# 2666      True         1         0
# 2667      True         0         1
#
# [2576 rows x 9 columns]

# %%
# Convert age from float dtype to int
df_cleaned['age'] = df_cleaned['age'].astype(int)
df_cleaned
# Out:
#       rank                personName  age  finalWorth  category  country  \
# 0        1                 Elon Musk   50      219000         8        0
# 1        2                Jeff Bezos   58      171000         0        0
# 2        3  Bernard Arnault & family   73      158000        11       17
# 3        4                Bill Gates   66      129000         0        0
# 4        5            Warren Buffett   91      118000         7        0
# ...    ...                       ...  ...         ...       ...      ...
# 2663  2578             Zhang Yuqiang   66        1000        10       69
# 2664  2578                Zhou Ruxin   59        1000         0       69
# 2665  2578         Wen Zhou & family   57        1000        10       69
# 2666  2578      Zhou Yifeng & family   43        1000        13       69
# 2667  2578   Zhuang Kuilong & family   59        1000        10       69
#
#       selfMade  gender_F  gender_M
# 0         True         0         1
# 1         True         0         1
# 2        False         0         1
# 3         True         0         1
# 4         True         0         1
# ...        ...       ...       ...
# 2663      True         0         1
# 2664      True         0         1
# 2665      True         0         1
# 2666      True         1         0
# 2667      True         0         1
#
# [2576 rows x 9 columns]

# %%
df_cleaned.dtypes
# Out:
# rank           int64
# personName    object
# age            int64
# finalWorth     int64
# category       int64
# country        int64
# selfMade        bool
# gender_F       uint8
# gender_M       uint8
# dtype: object

# %%
# saving cleaned data to csv

file_path = "Resources/cleaned_billionaire.csv"
df_cleaned.to_csv(file_path, index=False)
